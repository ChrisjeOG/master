# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import normalize
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('simpsons_dataset.csv').dropna()
df.head()
# Out:
#         raw_character_text                                       spoken_words
# 0              Miss Hoover  No, actually, it was a little of both. Sometim...
# 1             Lisa Simpson                             Where's Mr. Bergstrom?
# 2              Miss Hoover  I don't know. Although I'd sure like to talk t...
# 3             Lisa Simpson                         That life is worth living.
# 4  Edna Krabappel-Flanders  The polls will be open from now until the end ...

# %% [markdown]
# Elke waarde is nieuw (?) Geen een is hetzelfde

# %%
# df = df.loc[(df['raw_character_text'] == "Lisa Simpson") | (df['raw_character_text'] == "Bart Simpson")]
# df.head()
lisa = df.loc[df['raw_character_text'] == "Lisa Simpson"]

# %%
bart = df.loc[df['raw_character_text'] == "Bart Simpson"]

# %%
simpsons = pd.concat([lisa, bart])
simpsons.head()
# Out:
#    raw_character_text                                       spoken_words
# 1        Lisa Simpson                             Where's Mr. Bergstrom?
# 3        Lisa Simpson                         That life is worth living.
# 9        Lisa Simpson                      Mr. Bergstrom! Mr. Bergstrom!
# 11       Lisa Simpson                Do you know where I could find him?
# 13       Lisa Simpson  The train, how like him... traditional, yet en...

# %%
text = simpsons['spoken_words'].values.astype('U')

# %%
vect = CountVectorizer(stop_words='english') #Create the CV object, with English stop words
vect = vect.fit(text) #We fit the model with the words from the review text
feature_names = vect.get_feature_names() #Get the words from the vocabulary
print(f"There are {len(feature_names)} words in the vocabulary. A selection: {feature_names[500:520]}")
# Out:
# There are 14257 words in the vocabulary. A selection: ['anguished', 'angus', 'anima', 'animal', 'animals', 'animated', 'animation', 'animators', 'anka', 'ankle', 'ann', 'annapolis', 'anne', 'annie', 'anniversary', 'annnnd', 'announce', 'announcement', 'announcements', 'announcer']

# %%
matrix = vect.transform(text) #The transform method from the CountVectorizer object creates the matrix
#print(matrix[0:50,0:50])#Let's print a little part of the matrix: the first 50 words & documents

print(matrix[0:500, 0:500])
#haakjes zeggen in welke plek in de matrix het staat, want de sparse laat de nullen niet zien
# Out:
#   (14, 424)	1
#   (28, 266)	1
#   (31, 269)	1
#   (45, 192)	1
#   (46, 396)	1
#   (55, 325)	1
#   (59, 270)	1
#   (65, 325)	1
#   (81, 300)	1
#   (83, 281)	1
#   (92, 450)	1
#   (93, 397)	1
#   (97, 449)	1
#   (101, 24)	1
#   (101, 449)	1
#   (109, 129)	1
#   (110, 325)	1
#   (116, 38)	1
#   (116, 91)	1
#   (118, 446)	1
#   (120, 126)	1
#   (128, 52)	1
#   (128, 319)	1
#   (128, 343)	1
#   (130, 449)	1
#   :	:
#   (187, 479)	1
#   (188, 479)	1
#   (190, 450)	1
#   (235, 264)	1
#   (236, 264)	1
#   (248, 471)	1
#   (250, 207)	1
#   (312, 80)	1
#   (322, 319)	1
#   (323, 162)	1
#   (330, 384)	1
#   (332, 161)	1
#   (354, 427)	1
#   (358, 325)	1
#   (387, 147)	1
#   (387, 288)	1
#   (397, 425)	1
#   (415, 397)	1
#   (442, 316)	1
#   (447, 170)	1
#   (448, 307)	1
#   (452, 170)	1
#   (454, 170)	1
#   (465, 222)	1
#   (488, 219)	1

# %%
simpsons_mat = pd.DataFrame(matrix.toarray())
simpsons_mat.index = simpsons['raw_character_text'] 
simpsons_mat.columns = feature_names

# %%
#simpsons_mat#.iloc[0:4, 1000:1015]

# %%
# tada = pd.concat([simpsons, simpsons_mat], sort=False)
# tada

# %% [markdown]
# __Exercise 2__

# %%
X = simpsons_mat
X = normalize(X)
y = simpsons['raw_character_text']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
model.predict(X_test)
# Out:
# array(['Lisa Simpson', 'Lisa Simpson', 'Bart Simpson', ...,
#        'Bart Simpson', 'Bart Simpson', 'Bart Simpson'], dtype='<U12')

# %%
accuracy = model.score(X_test, y_test)

# %%
print(f'The accuracy is: {accuracy}' )
# Out:
# The accuracy is: 0.6385068762278978

# %%
simpsons['class'] = model.predict(X)

# %%
simpsons.head(500)
# Out:
#      raw_character_text                                       spoken_words  \
# 1          Lisa Simpson                             Where's Mr. Bergstrom?
# 3          Lisa Simpson                         That life is worth living.
# 9          Lisa Simpson                      Mr. Bergstrom! Mr. Bergstrom!
# 11         Lisa Simpson                Do you know where I could find him?
# 13         Lisa Simpson  The train, how like him... traditional, yet en...
# 15         Lisa Simpson                         I see he touched you, too.
# 37         Lisa Simpson                 Mr. Bergstrom! Hey, Mr. Bergstrom!
# 39         Lisa Simpson                                 Hey, Lisa, indeed.
# 41         Lisa Simpson  Oh, I mean, were you just going to leave, just...
# 43         Lisa Simpson  You can't go! You're the best teacher I'll eve...
# 45         Lisa Simpson                                        Oh, please.
# 47         Lisa Simpson                                But I need you too.
# 49         Lisa Simpson  I, I understand. Mr. Bergstrom, I'm going to m...
# 52         Lisa Simpson                          Thank you, Mr. Bergstrom.
# 54         Lisa Simpson  So, I guess this is it? It you don't mind I'll...
# 59         Lisa Simpson                                           Nothing.
# 61         Lisa Simpson                          Mr. Bergstrom left today.
# 63         Lisa Simpson                                He's gone. Forever.
# 65         Lisa Simpson                   I didn't think you'd understand.
# 67         Lisa Simpson  I'm glad I'm not crying because I would hate f...
# 69         Lisa Simpson          Yes, you! Baboon, baboon, baboon, baboon!
# 71         Lisa Simpson                                            Baboon!
# 77         Lisa Simpson                                                No!
# 80         Lisa Simpson        Look, if you just want me to forgive you --
# 88         Lisa Simpson                                              Yeah.
# 90         Lisa Simpson                                   You're so silly.
# 92         Lisa Simpson                           I don't have any banana.
# 94         Lisa Simpson              I'm sorry I called you a baboon, Dad.
# 116        Lisa Simpson  But Mom, I want to hear the witty banter of so...
# 184        Lisa Simpson     That music always sends a chill down my spine.
# ...                 ...                                                ...
# 8303       Lisa Simpson  No, Dad. You promised if Bart and I got C aver...
# 8333       Lisa Simpson                      I've never gotten a B before.
# 8334       Lisa Simpson  How could this have happened? I feel so dirty....
# 8335       Lisa Simpson  Oh Miss Hoover, there appears to be a mistake ...
# 8337       Lisa Simpson  Perhaps I'm not making myself clear. I think y...
# 8365       Lisa Simpson  So, Bart, will you be joining me in the bucoli...
# 8367       Lisa Simpson  A+! Oh, Bart, why didn't you at least forge pl...
# 8388       Lisa Simpson  Before I go to camp, I'll need boosters for ma...
# 8390       Lisa Simpson                        Don't patronize me, doctor.
# 8406       Lisa Simpson                          I'll write you every day.
# 8408       Lisa Simpson    If the pets die, don't replace them. I'll know!
# 8430       Lisa Simpson      This is a little more rustic than I expected.
# 8440       Lisa Simpson                          Are you sure that's safe?
# 8448       Lisa Simpson                           You're serving us gruel?
# 8461       Lisa Simpson                   I feel like I'm gonna die, Bart.
# 8463       Lisa Simpson                                      I meant soon.
# 8475       Lisa Simpson  Dear Mom and Dad, I no longer fear Hell, becau...
# 8477       Lisa Simpson   Our nature hikes have become grim death marches.
# 8481       Lisa Simpson  Our arts and crafts center is, in actuality, a...
# 8484       Lisa Simpson  Bart makes it through the days relying on his ...
# 8486       Lisa Simpson                     But I am far more pessimistic.
# 8488       Lisa Simpson  I am not sure if this letter will reach you as...
# 8490       Lisa Simpson  And now the effort of writing has made me ligh...
# 8505       Lisa Simpson    He's really having trouble keeping his balance.
# 8524       Lisa Simpson                                          Kowalski!
# 8526       Lisa Simpson                                            Wiggum!
# 8528       Lisa Simpson                                          Crandall!
# 8531       Lisa Simpson  Bart, you said you were gonna name it "Camp Fr...
# 8557       Lisa Simpson  Oh yeah? Who played your daughter in the short...
# 8560       Lisa Simpson  It is the real Krusty. Look at that pacemaker ...
#
#              class
# 1     Lisa Simpson
# 3     Bart Simpson
# 9     Lisa Simpson
# 11    Bart Simpson
# 13    Lisa Simpson
# 15    Lisa Simpson
# 37    Lisa Simpson
# 39    Bart Simpson
# 41    Bart Simpson
# 43    Bart Simpson
# 45    Bart Simpson
# 47    Bart Simpson
# 49    Lisa Simpson
# 52    Lisa Simpson
# 54    Lisa Simpson
# 59    Bart Simpson
# 61    Lisa Simpson
# 63    Bart Simpson
# 65    Lisa Simpson
# 67    Bart Simpson
# 69    Lisa Simpson
# 71    Lisa Simpson
# 77    Bart Simpson
# 80    Bart Simpson
# 88    Bart Simpson
# 90    Lisa Simpson
# 92    Bart Simpson
# 94    Lisa Simpson
# 116   Lisa Simpson
# 184   Lisa Simpson
# ...            ...
# 8303  Lisa Simpson
# 8333  Lisa Simpson
# 8334  Bart Simpson
# 8335  Bart Simpson
# 8337  Lisa Simpson
# 8365  Lisa Simpson
# 8367  Lisa Simpson
# 8388  Lisa Simpson
# 8390  Lisa Simpson
# 8406  Bart Simpson
# 8408  Bart Simpson
# 8430  Bart Simpson
# 8440  Bart Simpson
# 8448  Lisa Simpson
# 8461  Lisa Simpson
# 8463  Lisa Simpson
# 8475  Bart Simpson
# 8477  Lisa Simpson
# 8481  Lisa Simpson
# 8484  Bart Simpson
# 8486  Bart Simpson
# 8488  Bart Simpson
# 8490  Lisa Simpson
# 8505  Lisa Simpson
# 8524  Bart Simpson
# 8526  Bart Simpson
# 8528  Bart Simpson
# 8531  Lisa Simpson
# 8557  Bart Simpson
# 8560  Bart Simpson
#
# [500 rows x 3 columns]
